# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ### Prepare Data for K-Means Clustering
# * Select features for k-Means clustering
# * Convert time to numerical values
# * Convert dataframe to matrix
# * Output matrix as csv for selecting number of clusters (K)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn import cluster
from pandas import *

Route01_data = pd.read_csv('Route01_weather_redsox_holiday.csv')
del Route01_data['Unnamed: 0']

Route01_data['time'] = Route01_data['time'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
Route01_data.to_csv('Route01_Kmeans.csv')
Route01_data
# Out:
#       totaltraveltime  day  mean_temp  rain  snow  hail  snowfall  precip  \
# 0           10.833333    1         41     0     0     0         0    0.00
# 1           11.183333    1         41     0     0     0         0    0.00
# 2            9.300000    1         41     0     0     0         0    0.00
# 3            9.200000    1         41     0     0     0         0    0.00
# 4           11.400000    1         41     0     0     0         0    0.00
# 5           10.566667    1         41     0     0     0         0    0.00
# 6           11.650000    1         41     0     0     0         0    0.00
# 7            9.866667    1         41     0     0     0         0    0.00
# 8           12.850000    1         41     0     0     0         0    0.00
# 9           11.166667    1         41     0     0     0         0    0.00
# 10          13.100000    1         41     0     0     0         0    0.00
# 11           9.700000    1         41     0     0     0         0    0.00
# 12          12.916667    1         41     0     0     0         0    0.00
# 13          13.750000    1         41     0     0     0         0    0.00
# 14          15.483333    1         41     0     0     0         0    0.00
# 15          16.516667    1         41     0     0     0         0    0.00
# 16          17.066667    1         41     0     0     0         0    0.00
# 17          18.316667    1         41     0     0     0         0    0.00
# 18          13.816667    1         41     0     0     0         0    0.00
# 19          18.216667    1         41     0     0     0         0    0.00
# 20          17.066667    1         41     0     0     0         0    0.00
# 21          14.900000    1         41     0     0     0         0    0.00
# 22          13.333333    1         41     0     0     0         0    0.00
# 23          12.933333    1         41     0     0     0         0    0.00
# 24          13.716667    1         41     0     0     0         0    0.00
# 25          20.400000    1         41     0     0     0         0    0.00
# 26          12.766667    1         41     0     0     0         0    0.00
# 27          19.900000    1         41     0     0     0         0    0.00
# 28          15.466667    1         41     0     0     0         0    0.00
# 29          17.383333    1         41     0     0     0         0    0.00
# ...               ...  ...        ...   ...   ...   ...       ...     ...
# 2713        21.100000    2         43     1     0     0         0    0.35
# 2714        16.750000    2         43     1     0     0         0    0.35
# 2715        14.333333    2         43     1     0     0         0    0.35
# 2716        13.633333    2         43     1     0     0         0    0.35
# 2717        12.000000    2         43     1     0     0         0    0.35
# 2718        20.533333    2         43     1     0     0         0    0.35
# 2719        11.083333    2         43     1     0     0         0    0.35
# 2720        18.366667    2         43     1     0     0         0    0.35
# 2721        20.850000    2         43     1     0     0         0    0.35
# 2722        14.250000    2         43     1     0     0         0    0.35
# 2723        16.333333    2         43     1     0     0         0    0.35
# 2724        15.933333    2         43     1     0     0         0    0.35
# 2725        17.566667    2         43     1     0     0         0    0.35
# 2726        17.316667    2         43     1     0     0         0    0.35
# 2727        12.650000    2         43     1     0     0         0    0.35
# 2728        13.500000    2         43     1     0     0         0    0.35
# 2729        14.733333    2         43     1     0     0         0    0.35
# 2730        12.883333    2         43     1     0     0         0    0.35
# 2731        13.016667    2         43     1     0     0         0    0.35
# 2732         9.800000    2         43     1     0     0         0    0.35
# 2733        14.283333    2         43     1     0     0         0    0.35
# 2734        10.433333    2         43     1     0     0         0    0.35
# 2735        13.616667    2         43     1     0     0         0    0.35
# 2736        13.350000    2         43     1     0     0         0    0.35
# 2737        12.616667    2         43     1     0     0         0    0.35
# 2738         9.000000    2         43     1     0     0         0    0.35
#
#       holiday  friday_bforholiday  school_holiday
# 0           0                   0               0
# 1           0                   0               0
# 2           0                   0               0
# 3           0                   0               0
# 4           0                   0               0
# 5           0                   0               0
# 6           0                   0               0
# 7           0                   0               0
# 8           0                   0               0
# 9           0                   0               0
# 10          0                   0               0
# 11          0                   0               0
# 12          0                   0               0
# 13          0                   0               0
# 14          0                   0               0
# 15          0                   0               0
# 16          0                   0               0
# 17          0                   0               0
# 18          0                   0               0
# 19          0                   0               0
# 20          0                   0               0
# 21          0                   0               0
# 22          0                   0               0
# 23          0                   0               0
# 24          0                   0               0
# 25          0                   0               0
# 26          0                   0               0
# 27          0                   0               0
# 28          0                   0               0
# 29          0                   0               0
# ...       ...                 ...             ...
# 2713        0                   0               0
# 2714        0                   0               0
# 2715        0                   0               0
# 2716        0                   0               0
# 2717        0                   0               0
# 2718        0                   0               0
# 2719        0                   0               0
# 2720        0                   0               0
# 2721        0                   0               0
# 2722        0                   0               0
# 2723        0                   0               0
# 2724        0                   0               0
# 2725        0                   0               0
# 2726        0                   0               0
# 2727        0                   0               0
# 2728        0                   0               0
# 2729        0                   0               0
# 2730        0                   0               0
# 2731        0                   0               0
# 2732        0                   0               0
# 2733        0                   0               0
# 2734        0                   0               0
# 2735        0                   0               0
# 2736        0                   0               0
# 2737        0                   0               0
# 2738        0                   0               0
# 2739        0                   0               0
# 2740        0                   0               0
# 2741        0                   0               0
# 2742        0                   0               0
#
# [2743 rows x 16 columns]

# %% [markdown]
# ### Select Number of Clusters (K)
# * Silhoette Analysis

# %%
from __future__ import print_function
import pandas as pd
from pandas import *
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
# %matplotlib inline

print(__doc__)

# Generating the sample data from make_blobs
# This particular setting has one distict cluster and 3 clusters placed close
# together.
df = pd.read_csv('Route01_Kmeans.csv')
del df['date']
del df['prevtotaltraveltime']
del df['totaltraveltime']

X = df.as_matrix()
A = np.delete(X, 0, axis=1)

range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(A)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(A, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(A, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhoutte score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors)

 

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")
    
    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

    plt.show()
# Out:
# Automatically created module for IPython interactive environment
# For n_clusters = 2 The average silhouette_score is : 0.509261963784
# For n_clusters = 3 The average silhouette_score is : 0.509127284266
# For n_clusters = 4 The average silhouette_score is : 0.468577983636
# For n_clusters = 5 The average silhouette_score is : 0.492908575952
# For n_clusters = 6 The average silhouette_score is : 0.500750479007
# For n_clusters = 7 The average silhouette_score is : 0.535528027294
# For n_clusters = 8 The average silhouette_score is : 0.576627500125

# %% [markdown]
# ### Cluster Data using K-Means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn import cluster
from pandas import *


df = pd.read_csv('Route01_Kmeans.csv')
df = df.set_index('date')
data = df.as_matrix()
np.savetxt("Kmeans_data.csv", data, delimiter=",")
data = np.delete(data, 0, axis=1)


km = cluster.KMeans(n_clusters=4)
km.fit(data)
labels = km.labels_
results = pandas.DataFrame([df.index,df.totaltraveltime,df.time,df.day,df.mean_temp,df.rain,df.snow,df.hail,df.snowfall,df.precip,df.red_sox_game,df.prevlinkratio,df.prevtotaltraveltime,df.holiday,labels]).T
results.columns = ['date', 'totaltraveltime', 'time', 'day', 'mean_temp', 'rain', 'snow', 'hail', 'snowfall', 'precip', 'red_sox_game', 'prevlinkratio', 'prevtotaltraveltime','holiday', 'cluster']
results = results.sort('cluster')
results['date'] = pd.to_datetime(results['date'])
results.to_csv('Cluster_Results.csv')


import matplotlib.pyplot as plt

colors = [
    "red" if x == 0 else "blue" if x == 1 else "green" if x==2 else "cyan" if x==3 else "magenta" if x==4 else "yellow" if x==5 else "black" if x==6 else "white" for x in results['cluster']]
plt.scatter(results['time'], results['mean_temp'], s=5, c=colors)
plt.savefig("k-means_cluster.png")
